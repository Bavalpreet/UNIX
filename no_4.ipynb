# %%
'''
at the end of this tutorial , you will be able to :
- describe what a UNIX pipe is with an example
- name five filter commands
- differentiate between redirecting the standard out to 
  a file and piping it to another UNIX command.
'''

# %% [markdown]
# So, a filter is a program
# that takes inputs
# and transforms its inputs in some way,
# and the filter is placed after Unix pipe,
# it takes the output of the command
# on the other side of the pipe,
# and uses it as an input.
# Grep, more, less, sort and uniq,
# as we've just seen,
# are all commands in this category.
#
# FILTER COMMANDS
# grep
#
# more
#
# less
#
# sort
#
# uniq
#
# Grep will search for lines
# with a given string
# or look for a pattern in a given input stream.
# More, as you've seen,
# will show you as much as fits in your shell window,
# and similar to less.
# Sort will sort lines alphabetically or numerically
# in your input stream,
# and uniq will give you the unique lines
# in your input stream.
#
#
#
# ---
#
# Examples of filtering
#
# ls -la | more
#
# cat filename | wc
#
# man cat | grep file
#
# ls -l | grep txt | wc
#
# who | sort > current_users

# %% [markdown]
# Remember, we had the file fruits.txt
# in My1stDir directory.
#
# ls fruits.txt
#
#
# ---
#
# We wanted to count the number of unique fruit names in it.
# We said
# uniq
# fruits-sorted.txt
# and we piped it into
# fruits-unique.txt.
#
# uniq fruits-sorted.txt > fruits-unique.txt
#
#
# ---
#
# Let's try that.
# Uniq
# fruits-sorted.txt
# and I pipe it into the second command
# we wanted to get,
# wc minus l
# and we get that six beautifully as the number
# of fruits in it.
#
# uniq fruits-sorted.txt | wc -l
#
#
# ---
#
# Actually,
# we could have done even better.
# We didn't even need to have fruits-sorted.txt.
# We could have just typed,
# remember that original fruits file,
# let's cat that,
# fruits.txt.
# It had all these names of fruits in it.
# We could have just said sort fruits.txt
# and piped that into uniq as a command.
# That uniq will take the output of sort fruits.txt.
# What will that output will be?
# It will be this,
# right, sorted names
# and the uniq will pick the unique attributes in it,
# so we can pipe that into uniq
# and it's going to give us the number of unique fruits.
# Then we can take that and pipe it into wc minus l,
# and notice we get that same answer.
#
# cat fruits.txt
#
# sort fruits.txt
#
# sort fruits.txt | uniq
#
# sort fruits.txt | uniq | wc -l
#
# ---
#
# man is the manual page command in Unix.
# If I say man cat
# I'm gonna get the manual page
# for the cat command.
#
# man cat
#
#
#
# ---
#
# If you look at this manual page,
# you'll notice that file
# is one of the words
# that I use many times
# but exactly how many times?
# Right, we are trying to count it in this example.
#
# man cat | grep file | wc -l
#
# ---
#
# Lastly, let's look at a pipe and filter
# that shows what processes are running in my Unix system.
# A command that we haven't done before.
# Ps is a command for reporting process status,
# that stands for process status, ps, in Unix.
# We will use ps to show all processes associated
# with all the terminals.
#
#  ps
#
#  if I say ps minus aef
# I get like every
# process associated with all the terminals running my Unix-based system actually.
#
# ps -aef
#
# ps -aef | more
#
# ---
#
# If I just said
# ps aef sorted
# and maybe I'm gonna pipe that into more,
# so I could see now that they're all sorted,
#
# ps -aef | sort | more
#
# ---
#
# I can just say
# redirect this into out.txt.
# Now, out.txt will have the data in a form
# I would like to use it.
# I was able to in a way quickly prepare data
# for further analysis.
#
#
# ps -aef | sort > out.txt
